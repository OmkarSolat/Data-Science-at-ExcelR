# %% [markdown]
# <a href="https://colab.research.google.com/github/OmkarSolat/Data-Science-at-ExcelR/blob/main/Hierachical_Clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Hierachical Clustering**

# %%
#Importing Libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Loading Dataset
df = pd.read_csv("/content/Universities.csv")

# %%
df
# Out:
#             Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0          Brown  1310     89      22       13     22704        94
# 1        CalTech  1415    100      25        6     63575        81
# 2            CMU  1260     62      59        9     25026        72
# 3       Columbia  1310     76      24       12     31510        88
# 4        Cornell  1280     83      33       13     21864        90
# 5      Dartmouth  1340     89      23       10     32162        95
# 6           Duke  1315     90      30       12     31585        95
# 7     Georgetown  1255     74      24       12     20126        92
# 8        Harvard  1400     91      14       11     39525        97
# 9   JohnsHopkins  1305     75      44        7     58691        87
# 10           MIT  1380     94      30       10     34870        91
# 11  Northwestern  1260     85      39       11     28052        89
# 12     NotreDame  1255     81      42       13     15122        94
# ...

# %%
df.columns
# Out:
# Index(['Univ', 'SAT', 'Top10', 'Accept', 'SFRatio', 'Expenses', 'GradRate'], dtype='object')

# %% [markdown]
# # Feature scaling

# %%
#NORMALIZATION(minmax scaler)
#Transformation of single column needs "values.reshape(-1,1)"

from sklearn.preprocessing import MinMaxScaler
ms = MinMaxScaler()
df[['SAT','Top10','Accept','SFRatio','Expenses','GradRate']] = ms.fit_transform(df[['SAT','Top10','Accept','SFRatio','Expenses','GradRate']])

# %%
df
# Out:
#             Univ       SAT     Top10    Accept   SFRatio  Expenses  GradRate
# 0          Brown  0.743902  0.847222  0.105263  0.368421  0.255144  0.900000
# 1        CalTech  1.000000  1.000000  0.144737  0.000000  1.000000  0.466667
# 2            CMU  0.621951  0.472222  0.592105  0.157895  0.297461  0.166667
# 3       Columbia  0.743902  0.666667  0.131579  0.315789  0.415629  0.700000
# 4        Cornell  0.670732  0.763889  0.250000  0.368421  0.239835  0.766667
# 5      Dartmouth  0.817073  0.847222  0.118421  0.210526  0.427512  0.933333
# 6           Duke  0.756098  0.861111  0.210526  0.315789  0.416996  0.933333
# 7     Georgetown  0.609756  0.638889  0.131579  0.315789  0.208161  0.833333
# 8        Harvard  0.963415  0.875000  0.000000  0.263158  0.561699  1.000000
# 9   JohnsHopkins  0.731707  0.652778  0.394737  0.052632  0.910991  0.666667
# 10           MIT  0.914634  0.916667  0.210526  0.210526  0.476864  0.800000
# ...

# %%
df_norm = df.iloc[:,1:]

# %%
df_norm
# Out:
#          SAT     Top10    Accept   SFRatio  Expenses  GradRate
# 0   0.743902  0.847222  0.105263  0.368421  0.255144  0.900000
# 1   1.000000  1.000000  0.144737  0.000000  1.000000  0.466667
# 2   0.621951  0.472222  0.592105  0.157895  0.297461  0.166667
# 3   0.743902  0.666667  0.131579  0.315789  0.415629  0.700000
# 4   0.670732  0.763889  0.250000  0.368421  0.239835  0.766667
# 5   0.817073  0.847222  0.118421  0.210526  0.427512  0.933333
# 6   0.756098  0.861111  0.210526  0.315789  0.416996  0.933333
# 7   0.609756  0.638889  0.131579  0.315789  0.208161  0.833333
# 8   0.963415  0.875000  0.000000  0.263158  0.561699  1.000000
# 9   0.731707  0.652778  0.394737  0.052632  0.910991  0.666667
# 10  0.914634  0.916667  0.210526  0.210526  0.476864  0.800000
# 11  0.621951  0.791667  0.328947  0.263158  0.352609  0.733333
# 12  0.609756  0.736111  0.368421  0.368421  0.116965  0.900000
# 13  0.185366  0.138889  0.526316  0.631579  0.026991  0.433333
# ...

# %% [markdown]
# # Dendrogram

# %%
#creating dendrogram

import scipy.cluster.hierarchy as sch
sch.dendrogram(sch.linkage(df_norm,method='complete'))    #complete linkage
plt.show()

# %% [markdown]
# # Model bulding

# %%
#creating clusters

from sklearn.cluster import AgglomerativeClustering
hc = AgglomerativeClustering(n_clusters=5, affinity='euclidean', linkage='complete')
y_hc = hc.fit_predict(df_norm)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_agglomerative.py:1006: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(

# %%
y_hc
# Out:
# array([3, 4, 2, 3, 3, 0, 0, 3, 0, 0, 0, 3, 3, 1, 0, 1, 0, 1, 2, 0, 2, 3,
#        3, 1, 0])

# %%
#creating new column for predicted values
df['Clusters'] = y_hc

# %%
df
# Out:
#             Univ       SAT     Top10    Accept   SFRatio  Expenses  GradRate  \
# 0          Brown  0.743902  0.847222  0.105263  0.368421  0.255144  0.900000
# 1        CalTech  1.000000  1.000000  0.144737  0.000000  1.000000  0.466667
# 2            CMU  0.621951  0.472222  0.592105  0.157895  0.297461  0.166667
# 3       Columbia  0.743902  0.666667  0.131579  0.315789  0.415629  0.700000
# 4        Cornell  0.670732  0.763889  0.250000  0.368421  0.239835  0.766667
# 5      Dartmouth  0.817073  0.847222  0.118421  0.210526  0.427512  0.933333
# 6           Duke  0.756098  0.861111  0.210526  0.315789  0.416996  0.933333
# 7     Georgetown  0.609756  0.638889  0.131579  0.315789  0.208161  0.833333
# 8        Harvard  0.963415  0.875000  0.000000  0.263158  0.561699  1.000000
# 9   JohnsHopkins  0.731707  0.652778  0.394737  0.052632  0.910991  0.666667
# 10           MIT  0.914634  0.916667  0.210526  0.210526  0.476864  0.800000
# ...

# %%
#sorting dataframe based on clusters
df1 = df.sort_values(by=['Clusters'])
df1
# Out:
#             Univ       SAT     Top10    Accept   SFRatio  Expenses  GradRate  \
# 24          Yale  0.902439  0.930556  0.065789  0.263158  0.634397  0.966667
# 14     Princeton  0.902439  0.875000  0.000000  0.105263  0.392120  0.933333
# 10           MIT  0.914634  0.916667  0.210526  0.210526  0.476864  0.800000
# 9   JohnsHopkins  0.731707  0.652778  0.394737  0.052632  0.910991  0.666667
# 16      Stanford  0.865854  0.861111  0.078947  0.315789  0.505659  0.866667
# 19      UChicago  0.695122  0.652778  0.473684  0.368421  0.540832  0.666667
# 8        Harvard  0.963415  0.875000  0.000000  0.263158  0.561699  1.000000
# 5      Dartmouth  0.817073  0.847222  0.118421  0.210526  0.427512  0.933333
# 6           Duke  0.756098  0.861111  0.210526  0.315789  0.416996  0.933333
# 23    UWisconsin  0.195122  0.166667  0.723684  0.473684  0.057462  0.133333
# 13     PennState  0.185366  0.138889  0.526316  0.631579  0.026991  0.433333
# ...

# %%
#No. of clusters for each university
df1[['Univ','Clusters']]
# Out:
#             Univ  Clusters
# 24          Yale         0
# 14     Princeton         0
# 10           MIT         0
# 9   JohnsHopkins         0
# 16      Stanford         0
# 19      UChicago         0
# 8        Harvard         0
# 5      Dartmouth         0
# 6           Duke         0
# 23    UWisconsin         1
# 13     PennState         1
# 15        Purdue         1
# 17      TexasA&M         1
# 20     UMichigan         2
# 2            CMU         2
# 18    UCBerkeley         2
# 21         UPenn         3
# 22           UVA         3
# 0          Brown         3
# 7     Georgetown         3
# 4        Cornell         3
# 3       Columbia         3
# 11  Northwestern         3
# 12     NotreDame         3
# 1        CalTech         4
